# %%
from datasets import load_dataset
from IPython.display import display

# %%
ds = load_dataset("microsoft/cats_vs_dogs")
display(ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'labels'],
#         num_rows: 23410
#     })
# })

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'labels'],
#         num_rows: 23410
#     })
# })

# %%
ds["train"][1]
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x281>,
#  'labels': 0}

# %%
ds["train"][1]["image"]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x281>

# %%
ds["train"][1]["labels"]
# Out:
# 0

# %%
ds["train"][20000]["image"]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=359x500>

# %%
ds["train"][20000]["labels"]
# Out:
# 1

# %%
import pandas as pd

labels = [ds["train"][i]["labels"] for i in range(len(ds["train"]))]

label_series = pd.Series(labels)

label_counts = label_series.value_counts()

label_counts
# Out:
# 0    11741
# 1    11669
# Name: count, dtype: int64

# %%
train_sample = ds["train"].shuffle(seed=271828)

# %%
train_sample[0]["image"]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x420>

# %%
import numpy as np

# %%
image_array = np.array(train_sample[0]["image"])
image_shape = image_array.shape
print(image_shape)
# Out:
# (420, 500, 3)

# %%
image_shape = np.array(train_sample[1]["image"]).shape
print(image_shape)
# Out:
# (375, 500, 3)

# %%
X_train = [np.array(img) for img in train_sample["image"]]

y_train = np.array(train_sample["labels"])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train, y_train, test_size=0.2, random_state=271828
)

len(X_train), len(X_valid), len(y_train), len(y_valid)
# Out:
# (18728, 4682, 18728, 4682)

# %%
from PIL import Image

# %%
X_train_resized = [
    np.array(Image.fromarray(img).convert("L").resize((256, 256))) for img in X_train
]

X_valid_resized = [
    np.array(Image.fromarray(img).convert("L").resize((256, 256))) for img in X_valid
]

X_train_resized = np.array(X_train_resized)
X_valid_resized = np.array(X_valid_resized)

X_train_resized.shape, X_valid_resized.shape
# Out:
# ((18728, 256, 256), (4682, 256, 256))

# %%
Image.fromarray(X_train_resized[1])
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
X_train_resized = X_train_resized / 255.0
X_valid_resized = X_valid_resized / 255.0

# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense, Flatten

# %%
with tf.device("/cpu:0"):
    model = Sequential()
    model.add(Flatten(input_shape=(256, 256)))
    model.add(Dense(1024, activation="relu"))
    model.add(Dense(1024, activation="relu"))
    model.add(Dense(1024, activation="relu"))
    model.add(Dense(1, activation="sigmoid"))

    optimizer = tf.keras.optimizers.Adam(3e-4)
    model.compile(
        loss="binary_crossentropy",
        optimizer=optimizer,
        metrics=["accuracy"]
    )

    history = model.fit(
        X_train_resized,
        y_train,
        epochs=20,
        validation_data=(X_valid_resized, y_valid),
        batch_size=64,
    )
# Out:
# c:\Users\joaop\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 108s 356ms/step - accuracy: 0.5177 - loss: 1.9029 - val_accuracy: 0.5596 - val_loss: 0.6785
# Epoch 2/20
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 91s 309ms/step - accuracy: 0.5531 - loss: 0.6970 - val_accuracy: 0.5976 - val_loss: 0.6737
# Epoch 3/20
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 88s 299ms/step - accuracy: 0.5686 - loss: 0.6831 - val_accuracy: 0.5946 - val_loss: 0.6648
# Epoch 4/20
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 89s 302ms/step - accuracy: 0.5920 - loss: 0.6689 - val_accuracy: 0.5555 - val_loss: 0.6733
# Epoch 5/20
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 88s 299ms/step - accuracy: 0.5697 - loss: 0.6757 - val_accuracy: 0.5867 - val_loss: 0.6728
# Epoch 6/20
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 87s 297ms/step - accuracy: 0.5420 - loss: 0.6855 - val_accuracy: 0.5538 - val_loss: 0.6794
# Epoch 7/20
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 86s 294ms/step - accuracy: 0.5519 - loss: 0.6832 - val_accuracy: 0.5705 - val_loss: 0.6722
# Epoch 8/20
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 87s 295ms/step - accuracy: 0.5706 - loss: 0.6748 - val_accuracy: 0.5750 - val_loss: 0.6725
# Epoch 9/20
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 86s 295ms/step - accuracy: 0.5810 - loss: 0.6724 - val_accuracy: 0.5929 - val_loss: 0.6641
# Epoch 10/20
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 86s 295ms/step - accuracy: 0.5832 - loss: 0.6691 - val_accuracy: 0.5867 - val_loss: 0.6722
# Epoch 11/20
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 86s 292ms/step - accuracy: 0.5846 - loss: 0.6686 - val_accuracy: 0.6015 - val_loss: 0.6628
# Epoch 12/20
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 86s 292ms/step - accuracy: 0.5990 - loss: 0.6639 - val_accuracy: 0.5797 - val_loss: 0.6736
# Epoch 13/20
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 86s 292ms/step - accuracy: 0.5888 - loss: 0.6687 - val_accuracy: 0.6177 - val_loss: 0.6576
# Epoch 14/20
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 85s 291ms/step - accuracy: 0.6110 - loss: 0.6588 - val_accuracy: 0.6141 - val_loss: 0.6568
# Epoch 15/20
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 85s 291ms/step - accuracy: 0.6060 - loss: 0.6593 - val_accuracy: 0.6044 - val_loss: 0.6592
# Epoch 16/20
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 86s 292ms/step - accuracy: 0.5946 - loss: 0.6621 - val_accuracy: 0.6170 - val_loss: 0.6548
# Epoch 17/20
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 85s 290ms/step - accuracy: 0.6062 - loss: 0.6559 - val_accuracy: 0.6023 - val_loss: 0.6621
# Epoch 18/20
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 85s 290ms/step - accuracy: 0.6159 - loss: 0.6530 - val_accuracy: 0.6038 - val_loss: 0.6660
# Epoch 19/20
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 85s 289ms/step - accuracy: 0.6062 - loss: 0.6571 - val_accuracy: 0.6132 - val_loss: 0.6602
# Epoch 20/20
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 85s 291ms/step - accuracy: 0.6102 - loss: 0.6568 - val_accuracy: 0.6224 - val_loss: 0.6550
